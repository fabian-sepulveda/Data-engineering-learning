# %%
pip install pandas fastparquet pyarrow sqlalchemy psycopg2-binary
# Out:
# Collecting pandas
#   Downloading pandas-2.3.2-cp313-cp313-win_amd64.whl.metadata (19 kB)
# Collecting fastparquet
#   Downloading fastparquet-2024.11.0-cp313-cp313-win_amd64.whl.metadata (4.3 kB)
# Collecting pyarrow
#   Downloading pyarrow-21.0.0-cp313-cp313-win_amd64.whl.metadata (3.4 kB)
# Collecting sqlalchemy
#   Downloading sqlalchemy-2.0.43-cp313-cp313-win_amd64.whl.metadata (9.8 kB)
# Collecting psycopg2-binary
#   Downloading psycopg2_binary-2.9.10-cp313-cp313-win_amd64.whl.metadata (4.8 kB)
# Collecting numpy>=1.26.0 (from pandas)
#   Downloading numpy-2.3.3-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\fabia\appdata\roaming\python\python313\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\fabia\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.2)
# Collecting cramjam>=2.3 (from fastparquet)
#   Downloading cramjam-2.11.0-cp313-cp313-win_amd64.whl.metadata (681 bytes)
# Collecting fsspec (from fastparquet)
#   Downloading fsspec-2025.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: packaging in c:\users\fabia\appdata\roaming\python\python313\site-packages (from fastparquet) (25.0)
# Collecting greenlet>=1 (from sqlalchemy)
#   Downloading greenlet-3.2.4-cp313-cp313-win_amd64.whl.metadata (4.2 kB)
# Collecting typing-extensions>=4.6.0 (from sqlalchemy)
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: six>=1.5 in c:\users\fabia\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-2.3.2-cp313-cp313-win_amd64.whl (11.0 MB)
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ------------------------------------- -- 10.2/11.0 MB 52.1 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 43.6 MB/s  0:00:00
# Downloading fastparquet-2024.11.0-cp313-cp313-win_amd64.whl (673 kB)
#    ---------------------------------------- 0.0/673.3 kB ? eta -:--:--
#    ---------------------------------------- 673.3/673.3 kB 35.2 MB/s  0:00:00
# Downloading pyarrow-21.0.0-cp313-cp313-win_amd64.whl (26.1 MB)
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    ----------------------------------- ---- 23.3/26.1 MB 116.6 MB/s eta 0:00:01
#    ---------------------------------------- 26.1/26.1 MB 83.7 MB/s  0:00:00
# Downloading sqlalchemy-2.0.43-cp313-cp313-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 2.1/2.1 MB 37.1 MB/s  0:00:00
# Downloading psycopg2_binary-2.9.10-cp313-cp313-win_amd64.whl (2.6 MB)
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    ---------------------------------------- 2.6/2.6 MB 69.3 MB/s  0:00:00
# Downloading cramjam-2.11.0-cp313-cp313-win_amd64.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 1.7/1.7 MB 46.6 MB/s  0:00:00
# Downloading greenlet-3.2.4-cp313-cp313-win_amd64.whl (299 kB)
# Downloading numpy-2.3.3-cp313-cp313-win_amd64.whl (12.8 MB)
#    ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#    ---------------------------------------- 12.8/12.8 MB 61.4 MB/s  0:00:00
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading fsspec-2025.9.0-py3-none-any.whl (199 kB)
# Installing collected packages: pytz, typing-extensions, pyarrow, psycopg2-binary, numpy, greenlet, fsspec, cramjam, sqlalchemy, pandas, fastparquet
#
#    ----------------------------------------  0/11 [pytz]
#    ----------------------------------------  0/11 [pytz]
#    ------- --------------------------------  2/11 [pyarrow]
#    ------- --------------------------------  2/11 [pyarrow]
#    ------- --------------------------------  2/11 [pyarrow]
#    ------- --------------------------------  2/11 [pyarrow]
#    ------- --------------------------------  2/11 [pyarrow]
#    ------- --------------------------------  2/11 [pyarrow]
#    ------- --------------------------------  2/11 [pyarrow]
#    ------- --------------------------------  2/11 [pyarrow]
#    ------- --------------------------------  2/11 [pyarrow]
#    ------- --------------------------------  2/11 [pyarrow]
#    ------- --------------------------------  2/11 [pyarrow]
#    ------- --------------------------------  2/11 [pyarrow]
#    ------- --------------------------------  2/11 [pyarrow]
#    ------- --------------------------------  2/11 [pyarrow]
#    ------- --------------------------------  2/11 [pyarrow]
#    ------- --------------------------------  2/11 [pyarrow]
#    ------- --------------------------------  2/11 [pyarrow]
#    ---------- -----------------------------  3/11 [psycopg2-binary]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    ------------------ ---------------------  5/11 [greenlet]
#    ------------------ ---------------------  5/11 [greenlet]
#    --------------------- ------------------  6/11 [fsspec]
#    --------------------- ------------------  6/11 [fsspec]
#    --------------------- ------------------  6/11 [fsspec]
#    --------------------- ------------------  6/11 [fsspec]
#    --------------------- ------------------  6/11 [fsspec]
#    ------------------------- --------------  7/11 [cramjam]
#    ----------------------------- ----------  8/11 [sqlalchemy]
#    ----------------------------- ----------  8/11 [sqlalchemy]
#    ----------------------------- ----------  8/11 [sqlalchemy]
#    ----------------------------- ----------  8/11 [sqlalchemy]
#    ----------------------------- ----------  8/11 [sqlalchemy]
#    ----------------------------- ----------  8/11 [sqlalchemy]
#    ----------------------------- ----------  8/11 [sqlalchemy]
#    ----------------------------- ----------  8/11 [sqlalchemy]
#    ----------------------------- ----------  8/11 [sqlalchemy]
#    ----------------------------- ----------  8/11 [sqlalchemy]
#    ----------------------------- ----------  8/11 [sqlalchemy]
#    ----------------------------- ----------  8/11 [sqlalchemy]
#    ----------------------------- ----------  8/11 [sqlalchemy]
#    ----------------------------- ----------  8/11 [sqlalchemy]
#    ----------------------------- ----------  8/11 [sqlalchemy]
#    ----------------------------- ----------  8/11 [sqlalchemy]
#    ----------------------------- ----------  8/11 [sqlalchemy]
#    ----------------------------- ----------  8/11 [sqlalchemy]
#    ----------------------------- ----------  8/11 [sqlalchemy]
#    ----------------------------- ----------  8/11 [sqlalchemy]
#    ----------------------------- ----------  8/11 [sqlalchemy]
#    ----------------------------- ----------  8/11 [sqlalchemy]
#    ----------------------------- ----------  8/11 [sqlalchemy]
#    ----------------------------- ----------  8/11 [sqlalchemy]
#    ----------------------------- ----------  8/11 [sqlalchemy]
#    ----------------------------- ----------  8/11 [sqlalchemy]
#    ----------------------------- ----------  8/11 [sqlalchemy]
#    ----------------------------- ----------  8/11 [sqlalchemy]
#    ----------------------------- ----------  8/11 [sqlalchemy]
#    ----------------------------- ----------  8/11 [sqlalchemy]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    -------------------------------- -------  9/11 [pandas]
#    ------------------------------------ --- 10/11 [fastparquet]
#    ------------------------------------ --- 10/11 [fastparquet]
#    ---------------------------------------- 11/11 [fastparquet]
#
# Successfully installed cramjam-2.11.0 fastparquet-2024.11.0 fsspec-2025.9.0 greenlet-3.2.4 numpy-2.3.3 pandas-2.3.2 psycopg2-binary-2.9.10 pyarrow-21.0.0 pytz-2025.2 sqlalchemy-2.0.43 typing-extensions-4.15.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.3.2'

# %%
# Read csv file, first 100 rows

df = pd.read_csv("yellow_tripdata_2021-01_test.csv", nrows=100)

# %%
df
# Out:
#     VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0          1  2021-01-01 00:30:10   2021-01-01 00:36:12                1
# 1          1  2021-01-01 00:51:20   2021-01-01 00:52:19                1
# 2          1  2021-01-01 00:43:30   2021-01-01 01:11:06                1
# 3          1  2021-01-01 00:15:48   2021-01-01 00:31:01                0
# 4          2  2021-01-01 00:31:49   2021-01-01 00:48:21                1
# ..       ...                  ...                   ...              ...
# 95         2  2021-01-01 00:12:41   2021-01-01 00:26:47                1
# 96         2  2021-01-01 00:23:29   2021-01-01 00:35:03                2
# 97         2  2021-01-01 00:46:17   2021-01-01 00:54:25                2
# 98         2  2021-01-01 00:28:16   2021-01-01 00:51:44                1
# 99         2  2021-01-01 00:42:35   2021-01-01 00:54:41                3
#
#     trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            2.10           1                  N           142            43
# 1            0.20           1                  N           238           151
# 2           14.70           1                  N           132           165
# 3           10.60           1                  N           138           132
# 4            4.94           1                  N            68            33
# ..            ...         ...                ...           ...           ...
# 95           4.13           1                  N           161           226
# 96           4.12           1                  N           162            74
# 97           2.22           1                  N           144           170
# 98           7.11           1                  N           264           264
# 99           1.61           1                  N           229           237
#
#     payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0              2          8.0    3.0      0.5        0.00           0.0
# 1              2          3.0    0.5      0.5        0.00           0.0
# 2              1         42.0    0.5      0.5        8.65           0.0
# 3              1         29.0    0.5      0.5        6.05           0.0
# 4              1         16.5    0.5      0.5        4.06           0.0
# ..           ...          ...    ...      ...         ...           ...
# 95             1         14.5    0.5      0.5        3.66           0.0
# 96             2         13.5    0.5      0.5        0.00           0.0
# 97             1          9.0    0.5      0.5        2.56           0.0
# 98             2         23.5    0.5      0.5        0.00           0.0
# 99             2          9.5    0.5      0.5        0.00           0.0
#
#     improvement_surcharge  total_amount  congestion_surcharge
# 0                     0.3         11.80                   2.5
# 1                     0.3          4.30                   0.0
# 2                     0.3         51.95                   0.0
# 3                     0.3         36.35                   0.0
# 4                     0.3         24.36                   2.5
# ..                    ...           ...                   ...
# 95                    0.3         21.96                   2.5
# 96                    0.3         17.30                   2.5
# 97                    0.3         15.36                   2.5
# 98                    0.3         24.80                   0.0
# 99                    0.3         13.30                   2.5
#
# [100 rows x 18 columns]

# %%
print(pd.io.sql.get_schema(df, name="yellow_taxi_data"))
# Out:
# CREATE TABLE "yellow_taxi_data" (
# "VendorID" INTEGER,
#   "tpep_pickup_datetime" TEXT,
#   "tpep_dropoff_datetime" TEXT,
#   "passenger_count" INTEGER,
#   "trip_distance" REAL,
#   "RatecodeID" INTEGER,
#   "store_and_fwd_flag" TEXT,
#   "PULocationID" INTEGER,
#   "DOLocationID" INTEGER,
#   "payment_type" INTEGER,
#   "fare_amount" REAL,
#   "extra" REAL,
#   "mta_tax" REAL,
#   "tip_amount" REAL,
#   "tolls_amount" REAL,
#   "improvement_surcharge" REAL,
#   "total_amount" REAL,
#   "congestion_surcharge" REAL
# )

# %%
# Ajustamos el datetime, ya que no debe ser TEXT

df.tpep_pickup_datetime =  pd.to_datetime(df["tpep_pickup_datetime"])
df.tpep_dropoff_datetime =  pd.to_datetime(df["tpep_dropoff_datetime"])

# %%
print(pd.io.sql.get_schema(df, name="yellow_taxi_data"))
# Out:
# CREATE TABLE "yellow_taxi_data" (
# "VendorID" INTEGER,
#   "tpep_pickup_datetime" TIMESTAMP,
#   "tpep_dropoff_datetime" TIMESTAMP,
#   "passenger_count" INTEGER,
#   "trip_distance" REAL,
#   "RatecodeID" INTEGER,
#   "store_and_fwd_flag" TEXT,
#   "PULocationID" INTEGER,
#   "DOLocationID" INTEGER,
#   "payment_type" INTEGER,
#   "fare_amount" REAL,
#   "extra" REAL,
#   "mta_tax" REAL,
#   "tip_amount" REAL,
#   "tolls_amount" REAL,
#   "improvement_surcharge" REAL,
#   "total_amount" REAL,
#   "congestion_surcharge" REAL
# )

# %%
# Creamos la conexión a postgres

from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql://root:root@localhost:5431/ny_taxi')

# %%
engine.connect()

# %%
print(pd.io.sql.get_schema(df, name="yellow_taxi_data", con=engine))
# Out:
# CREATE TABLE yellow_taxi_data (
# 	"VendorID" BIGINT,
# 	tpep_pickup_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	tpep_dropoff_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	passenger_count BIGINT,
# 	trip_distance FLOAT(53),
# 	"RatecodeID" BIGINT,
# 	store_and_fwd_flag TEXT,
# 	"PULocationID" BIGINT,
# 	"DOLocationID" BIGINT,
# 	payment_type BIGINT,
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	improvement_surcharge FLOAT(53),
# 	total_amount FLOAT(53),
# 	congestion_surcharge FLOAT(53)
# )

# %%
# Ahora vamos ingresar toda la información, no solo lo que seria las 100 primeras columnas}

# Esto lo haremos con batch (Paquetes de información)

df_iter = pd.read_csv("yellow_tripdata_2021-01_test.csv", iterator=True, chunksize=10000)

# %%
df = next(df_iter)

# %%
len(df)
# Out:
# 10000

# %%
df.tpep_pickup_datetime =  pd.to_datetime(df["tpep_pickup_datetime"])
df.tpep_dropoff_datetime =  pd.to_datetime(df["tpep_dropoff_datetime"])

# %%
df.head(n=0).to_sql(name="yellow_taxi_data", con=engine, if_exists='replace')
# Out:
# 0

# %%
# Con el codigo anterior creamos unicamente los nombres de las columnas

# %%
# Ahora que sabemos que la comunicación se realiza podemos agregar el resto

df.to_sql(name="yellow_taxi_data", con=engine, if_exists='replace')
# Out:
# 1000

# %%
# Lo anterior solo agrego un solo chunk
# Este codigo agrega cada chunk
while True:
    try:
        df = next(df_iter)
        df.tpep_pickup_datetime =  pd.to_datetime(df["tpep_pickup_datetime"])
        df.tpep_dropoff_datetime =  pd.to_datetime(df["tpep_dropoff_datetime"])
        df.to_sql(name="yellow_taxi_data", con=engine, if_exists='append')
        print("Another chunk inserted")
    except StopIteration:
        break
# Out:
# Another chunk inserted
# Another chunk inserted
# Another chunk inserted
# Another chunk inserted
# Another chunk inserted
# Another chunk inserted
# Another chunk inserted
# Another chunk inserted
# Another chunk inserted
